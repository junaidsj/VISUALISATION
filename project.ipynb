# %%
import yfinance as yf
tesla=yf.Ticker("Tsla")
tesla_data=tesla.history(period="max")
tesla_data=tesla_data.reset_index()
print(tesla_data.tail())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
import yfinance as yf
tesla=yf.Ticker("Tsla")
tesla_data=tesla.history(period="max")
tesla_data=tesla_data.reset_index()
print(tesla_data.tail())
# Out:
#                           Date        Open        High         Low  \
# 3706 2025-03-24 00:00:00-04:00  258.079987  278.640015  256.329987
# 3707 2025-03-25 00:00:00-04:00  283.600006  288.200012  271.279999
# 3708 2025-03-26 00:00:00-04:00  282.660004  284.899994  266.510010
# 3709 2025-03-27 00:00:00-04:00  272.480011  291.850006  271.820007
# 3710 2025-03-28 00:00:00-04:00  275.579987  276.100006  260.570007
#
#            Close     Volume  Dividends  Stock Splits
# 3706  278.390015  169079900        0.0           0.0
# 3707  288.140015  150361500        0.0           0.0
# 3708  272.059998  153629800        0.0           0.0
# 3709  273.130005  162572100        0.0           0.0
# 3710  263.549988  123226900        0.0           0.0

# %%
import yfinance as yf
gme=yf.Ticker("GME")
gme_data=tesla.history(period="max")
gme_data=tesla_data.reset_index()
print(tesla_data.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
import yfinance as yf
gme=yf.Ticker("GME")
gme_data=tesla.history(period="max")
gme_data=tesla_data.reset_index()
print(tesla_data.tail())
# Out:
#                           Date        Open        High         Low  \
# 3706 2025-03-24 00:00:00-04:00  258.079987  278.640015  256.329987
# 3707 2025-03-25 00:00:00-04:00  283.600006  288.200012  271.279999
# 3708 2025-03-26 00:00:00-04:00  282.660004  284.899994  266.510010
# 3709 2025-03-27 00:00:00-04:00  272.480011  291.850006  271.820007
# 3710 2025-03-28 00:00:00-04:00  275.579987  276.100006  260.570007
#
#            Close     Volume  Dividends  Stock Splits
# 3706  278.390015  169079900        0.0           0.0
# 3707  288.140015  150361500        0.0           0.0
# 3708  272.059998  153629800        0.0           0.0
# 3709  273.130005  162572100        0.0           0.0
# 3710  263.549988  123226900        0.0           0.0

# %%
import matplotlib.pyplot as plt 
import yfinance as yf
tesla=yf.Ticker("Tsla")
tesla_data=tesla.history(period="max")
tesla_data=tesla_data.reset_index()
plt.figure(figsize=(10,5))
plt.plot(tesla_data["Date"],tesla_data["Close"],label="Tesla Closing Stock")
plt.xlabel("Year")
plt.ylabel("Stock Price in USD")
plt.title("Tesla Stock of all time")
plt.legend()
plt.grid()
plt.show()
print(tesla_data.tail())
# Out:
#                           Date        Open        High         Low  \
# 3706 2025-03-24 00:00:00-04:00  258.079987  278.640015  256.329987
# 3707 2025-03-25 00:00:00-04:00  283.600006  288.200012  271.279999
# 3708 2025-03-26 00:00:00-04:00  282.660004  284.899994  266.510010
# 3709 2025-03-27 00:00:00-04:00  272.480011  291.850006  271.820007
# 3710 2025-03-28 00:00:00-04:00  275.579987  276.100006  260.570007
#
#            Close     Volume  Dividends  Stock Splits
# 3706  278.390015  169079900        0.0           0.0
# 3707  288.140015  150361500        0.0           0.0
# 3708  272.059998  153629800        0.0           0.0
# 3709  273.130005  162572100        0.0           0.0
# 3710  263.549988  123226900        0.0           0.0

# %%
import matplotlib.pyplot as plt 
import yfinance as yf
gme=yf.Ticker("GME")
gme_data=gme.history(period="max")
gme_data=gme_data.reset_index()
plt.figure(figsize=(10,5))
plt.plot(gme_data["Date"],gme_data["Close"],label="GME Closing Stock")
plt.xlabel("Year")
plt.ylabel("Stock Price in USD")
plt.title("GAMESTOP(GME) Stock of all time")
plt.legend()
plt.grid()
plt.show()
print(tesla_data.tail())
# Out:
#                           Date        Open        High         Low  \
# 3706 2025-03-24 00:00:00-04:00  258.079987  278.640015  256.329987
# 3707 2025-03-25 00:00:00-04:00  283.600006  288.200012  271.279999
# 3708 2025-03-26 00:00:00-04:00  282.660004  284.899994  266.510010
# 3709 2025-03-27 00:00:00-04:00  272.480011  291.850006  271.820007
# 3710 2025-03-28 00:00:00-04:00  275.579987  276.100006  260.570007
#
#            Close     Volume  Dividends  Stock Splits
# 3706  278.390015  169079900        0.0           0.0
# 3707  288.140015  150361500        0.0           0.0
# 3708  272.059998  153629800        0.0           0.0
# 3709  273.130005  162572100        0.0           0.0
# 3710  263.549988  123226900        0.0           0.0
